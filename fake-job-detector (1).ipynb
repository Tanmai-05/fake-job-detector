# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/Colab Notebooks/fake-job-detector.zip"
extract_path = "/content/fake-job-detector"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %cd /content/fake-job-detector
# Out:
# /content/fake-job-detector

# %%
import os
os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks',
#  'Untitled spreadsheet (1).gsheet',
#  'TANMAI resume (1)_compressed.pdf',
#  'Untitled document.gdoc',
#  'Untitled spreadsheet.gsheet',
#  'project',
#  'Screenshot 2025-05-25 132454.png']

# %%
# !pip install transformers datasets accelerate scikit-learn pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !python bert_train.py
# Out:
# python3: can't open file '/content/fake-job-detector/bert_train.py': [Errno 2] No such file or directory

# %%
# !ls /content/fake-job-detector
# Out:
# fake-job-detector

# %%
# !ls /content/fake-job-detector/fake-job-detector
# Out:
# app.py	bert_train.py  data  models  README.md	requirements.txt  src

# %%
# !python bert_train.py
# Out:
# python3: can't open file '/content/fake-job-detector/bert_train.py': [Errno 2] No such file or directory

# %%
# !find /content/fake-job-detector -name "bert_train.py"
# Out:
# /content/fake-job-detector/fake-job-detector/bert_train.py

# %%
# %cd /content/fake-job-detector/fake-job-detector
# Out:
# /content/fake-job-detector/fake-job-detector

# %%
# !python bert_train.py
# Out:
# 2025-06-21 14:04:40.855953: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750514681.103708    6232 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750514681.182121    6232 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-21 14:04:41.714509: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python /content/fake-job-detector/fake-job-detector/bert_predict.py
# Out:
# 2025-06-21 15:14:49.792779: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750518889.813122   32201 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750518889.819354   32201 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-21 15:14:49.841868: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 88.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 125.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 8.7 MB/s eta 0:00:00
# ...

# %%
# !pip install streamlit transformers torch pyngrok --quiet

# %%
# %cd /content/fake-job-detector/fake-job-detector
# Out:
# /content/fake-job-detector/fake-job-detector

# %%
# !ls
# Out:
# app.py		 bert_train.py	logs	README.md	  src	    wandb
# bert_predict.py  data		models	requirements.txt  untitled

# %%
# !ngrok config add-authtoken 2ypAeqjjeKfHnPzmW5EvHUFGxGI_4hL94T4NozB3qxNyQJD5X
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok
# !pkill streamlit
public_url = ngrok.connect(8501)
print("🌐 Web App URL:", public_url)
# !streamlit run app.py &>/dev/null &
# Out:
# 🌐 Web App URL: NgrokTunnel: "https://f0d2-34-16-149-72.ngrok-free.app" -> "http://localhost:8501"
